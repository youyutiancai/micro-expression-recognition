# %%
import pandas as pd
import numpy as np
import cv2
from config import *

# %%
for i in range(4):
#     left_videos, left_labels = regenerateVideo('_left_eye', i + 1, 20, 30)
#     np.savez('./videos/videos_sq' + str(i + 1) + '/leftEye.npz', videos = left_videos, labels = left_labels)
#     right_videos, right_labels = regenerateVideo('_right_eye', i + 1, 20, 30)
#     np.savez('./videos/videos_sq' + str(i + 1) + '/rightEye.npz', videos = right_videos, labels = right_labels)
#     mn_videos, mn_labels = regenerateVideo('_mouth', i + 1, 50, 30)
#     np.savez('./videos/videos_sq' + str(i + 1) + '/mouth.npz', videos = mn_videos, labels = mn_labels)
#     whole_videos, whole_labels = regenerateVideo('', i + 1, 90, 75)
#     np.savez('./videos/videos_sq' + str(i + 1) + '/face.npz', videos = whole_videos, labels = whole_labels)
#     face_videos, face_labels = regenerateVideo('', i + 1, 90, 75)
#     np.savez('./videos/videos_sq' + str(i + 1) + '/face_sign.npz', videos = face_videos, labels = face_labels)
    face_videos, face_labels = regenerateVideo('_face', i + 1, 85, 85)
    np.savez('./videos/videos_sq' + str(i + 1) + '/whole_face.npz', videos = face_videos, labels = face_labels)
# Out:
# finish
# finish
# finish
# finish

# %%
image = cv2.imread('./database/CASME2/Cropped/sub01/EP02_01f/reg_img46.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
frame = maxPxGrid(image, 90, 75)
plt.imshow(frame, cmap = 'gray')

# %%
plt.imshow(face_videos[0][2], cmap = 'gray')

# %%
left_videos, left_labels = regenerateVideo('_left_eye', 1 * 1, 20, 30)
right_videos, right_labels = regenerateVideo('_right_eye', 1 * 1, 20, 30)
mn_videos, mn_labels = regenerateVideo('_mouth', 1 * 1, 50, 30)
whole_videos, whole_labels = regenerateVideo('', 1 * 1, 90, 75)
np.savez('./videos_sq1/leftEye.npz', videos = left_videos, labels = left_labels)
np.savez('./videos_sq1/rightEye.npz', videos = right_videos, labels = right_labels)
np.savez('./videos_sq1/mouth.npz', videos = mn_videos, labels = mn_labels)
np.savez('./videos_sq1/face.npz', videos = whole_videos, labels = whole_labels)
# Out:
# finish
# finish
# finish
# finish

# %%
left_videos, left_labels = regenerateVideo('_left_eye', 2 * 2, 20, 30)
right_videos, right_labels = regenerateVideo('_right_eye', 2 * 2, 20, 30)
mn_videos, mn_labels = regenerateVideo('_mouth', 2 * 2, 50, 30)
whole_videos, whole_labels = regenerateVideo('', 2 * 2, 90, 75)
np.savez('./videos_sq2/leftEye.npz', videos = left_videos, labels = left_labels)
np.savez('./videos_sq2/rightEye.npz', videos = right_videos, labels = right_labels)
np.savez('./videos_sq2/mouth.npz', videos = mn_videos, labels = mn_labels)
np.savez('./videos_sq2/face.npz', videos = whole_videos, labels = whole_labels)
# Out:
# finish
# finish
# finish
# finish

# %%
left_videos, left_labels = regenerateVideo('_left_eye', 1 * 1, 20, 30)
right_videos, right_labels = regenerateVideo('_right_eye', 1 * 1, 20, 30)
mn_videos, mn_labels = regenerateVideo('_mouth', 1 * 1, 50, 30)
whole_videos, whole_labels = regenerateVideo('', 1 * 1, 90, 75)
np.savez('./videos_test_sq1/leftEye.npz', videos = left_videos, labels = left_labels)
np.savez('./videos_test_sq1/rightEye.npz', videos = right_videos, labels = right_labels)
np.savez('./videos_test_sq1/mouth.npz', videos = mn_videos, labels = mn_labels)
np.savez('./videos_test_sq1/face.npz', videos = whole_videos, labels = whole_labels)
# Out:
# finish
# finish
# finish
# finish

# %%
left_videos, left_labels = regenerateVideo('_left_eye', 2 * 2, 20, 30)
right_videos, right_labels = regenerateVideo('_right_eye', 2 * 2, 20, 30)
mn_videos, mn_labels = regenerateVideo('_mouth', 2 * 2, 50, 30)
whole_videos, whole_labels = regenerateVideo('', 2 * 2, 90, 75)
np.savez('./videos_test_sq2/leftEye.npz', videos = left_videos, labels = left_labels)
np.savez('./videos_test_sq2/rightEye.npz', videos = right_videos, labels = right_labels)
np.savez('./videos_test_sq2/mouth.npz', videos = mn_videos, labels = mn_labels)
np.savez('./videos_test_sq2/face.npz', videos = whole_videos, labels = whole_labels)
# Out:
# finish
# finish
# finish
# finish

# %%
left_videos, left_labels = regenerateVideo('_left_eye', 3 * 3, 20, 30)
right_videos, right_labels = regenerateVideo('_right_eye', 3 * 3, 20, 30)
mn_videos, mn_labels = regenerateVideo('_mouth', 3 * 3, 50, 30)
whole_videos, whole_labels = regenerateVideo('', 3 * 3, 90, 75)
np.savez('./videos_test_sq3/leftEye.npz', videos = left_videos, labels = left_labels)
np.savez('./videos_test_sq3/rightEye.npz', videos = right_videos, labels = right_labels)
np.savez('./videos_test_sq3/mouth.npz', videos = mn_videos, labels = mn_labels)
np.savez('./videos_test_sq3/face.npz', videos = whole_videos, labels = whole_labels)
# Out:
# finish
# finish
# finish
# finish

# %%
a = [-4, 2, 3, 6]
np.sign(a)
# Out:
# array([-1,  1,  1,  1])
